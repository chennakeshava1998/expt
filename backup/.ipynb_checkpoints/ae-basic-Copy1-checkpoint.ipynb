# %%
import tensorflow as tf
from TPM_from_VCS.data import toy_data_generator
from TPM_from_VCS.models.etp import etp
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def get_diagram(cost_history, steps):
    plt.plot(np.arange(steps), cost_history)
    plt.xlabel('Epochs')
    plt.ylabel('MSE')
    plt.title('Training Error')
    plt.show()

# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

##########################
### WRAPPER FUNCTIONS
##########################

def fully_connected(input_tensor, output_nodes,
                    activation=None, seed=None,
                    name='fully_connected'):

    with tf.name_scope(name):
        input_nodes = input_tensor.get_shape().as_list()[1]
        weights = tf.Variable(tf.truncated_normal(shape=(input_nodes,
                                                         output_nodes),
                                                  mean=0.0,
                                                  stddev=0.1,
                                                  dtype=tf.float32,
                                                  seed=seed),
                              name='weights')
        biases = tf.Variable(tf.zeros(shape=[output_nodes]), name='biases')

        act = tf.matmul(input_tensor, weights) + biases
        if activation is not None:
            act = activation(act)
        return act


##########################
### DATASET
##########################

mnist = input_data.read_data_sets("./", validation_size=0)


##########################
### SETTINGS
##########################


# Hyperparameters
learning_rate = 0.01
training_epochs = 60
batch_size = 128

# Architecture
hidden_size = 2
input_size = 5
# image_width = 28
MAX_VC_DIM = 10
MAX_NODES = 1000

# Other
print_interval = 20
random_seed = 123


##########################
### GRAPH DEFINITION
##########################

g = tf.Graph()
with g.as_default():
    
    tf.set_random_seed(random_seed)
    
#     cost_history = []

    # Input data
    input_layer = tf.placeholder(tf.float32, [None, input_size],
                                 name='input')

    ###########
    # Encoder
    ###########
    
    hidden_layer0 = fully_connected(input_layer, hidden_size * 15, 
                                   activation=None, 
                                   name='hidden0')
    
    hidden_layer1 = fully_connected(hidden_layer0, hidden_size * 5, 
                                   activation=None, 
                                   name='hidden1')
    
    hidden_layer2 = fully_connected(hidden_layer1, hidden_size, 
                                   activation=None, 
                                   name='hidden2')
    
    temp_out = tf.stack(hidden_layer2, name='temp_out', axis=0)
    temp = tf.identity(temp_out, name='reduced_dim')
    
    etp_loss = etp.get_best_etp(temp, inp)
    
    print('temp_out = {}'.format(temp_out))
    
    hidden_layer3 = fully_connected(hidden_layer2, hidden_size * 5, 
                                   activation=None, 
                                   name='hidden3')
    
    hidden_layer4 = fully_connected(hidden_layer3, hidden_size * 15, 
                                   activation=None, 
                                   name='hidden4')
    
    
    
    ###########
    # Decoder
    ###########
    
    logits = fully_connected(hidden_layer3, input_size, 
                             activation=None, name='logits')
    # note MNIST pixels are normalized to 0-1 range
#     out_layer = tf.nn.sigmoid(logits, name='decoding') 
    
    # set the output layer to be the same as logits. TODO: try relu activation also. Change the cost funcion definition only
    out_layer = tf.nn.relu(logits, name='decoding') 
    
    ##################
    # Loss & Optimizer
    ##################
    
    cost = tf.reduce_mean(tf.losses.mean_squared_error(
        labels=input_layer, predictions=logits), name='cost')
    
#     cost_history.append(cost)
    
    optimizer = tf.train.AdamOptimizer(learning_rate)
    train = optimizer.minimize(cost, name='train')

    # Saver to save session for reuse
    saver = tf.train.Saver()
# Out:
# Extracting ./train-images-idx3-ubyte.gz
# Extracting ./train-labels-idx1-ubyte.gz
# Extracting ./t10k-images-idx3-ubyte.gz
# Extracting ./t10k-labels-idx1-ubyte.gz
# temp_out = Tensor("hidden2/add:0", shape=(?, 2), dtype=float32)

# %%
batch_x = toy_data_generator.create_dataset(1)

batch_x[0][0]

len(batch_x)
# Out:
# 17

# %%
import numpy as np

##########################
### TRAINING & EVALUATION
##########################
    
with tf.Session(graph=g) as sess:
    sess.run(tf.global_variables_initializer())
    cost_history = []
    steps = 0
    
    np.random.seed(random_seed) # random seed for mnist iterator
    for epoch in range(training_epochs):
        avg_cost = 0.
#         total_batch = mnist.train.num_examples // batch_size
        total_batch = 500
        batch_x = toy_data_generator.create_dataset(1)
        
        for i in range(total_batch):
            
            
            for z in range(len(batch_x)):
                _, c = sess.run(['train', 'cost:0'], 
                                feed_dict={'input:0': np.reshape(batch_x[z][0], (-1, 5))})
                avg_cost += c
                
            cost_history.append(c)
            steps+=1
                
            
            if not i % print_interval:
                print("Minibatch: %03d | Cost:    %.3f" % (i + 1, c))
                
            if not steps % 5000:
                get_diagram(cost_history, steps)
                
    
        print("Epoch:     %03d | AvgCost: %.3f" % (epoch + 1, avg_cost / (i + 1)))
    
    saver.save(sess, save_path='./autoencoder.ckpt')
# Out:
# Minibatch: 001 | Cost:    105493.086
# Minibatch: 021 | Cost:    63970.074
# Minibatch: 041 | Cost:    69487.250
# Minibatch: 061 | Cost:    68795.891
# Minibatch: 081 | Cost:    72824.391
# Minibatch: 101 | Cost:    70475.547
# Minibatch: 121 | Cost:    72605.820
# Minibatch: 141 | Cost:    72966.383
# Minibatch: 161 | Cost:    75161.859
# Minibatch: 181 | Cost:    74850.234
# Minibatch: 201 | Cost:    75301.328
# Minibatch: 221 | Cost:    83239.438
# Minibatch: 241 | Cost:    71232.867
# Minibatch: 261 | Cost:    72514.906
# Minibatch: 281 | Cost:    74281.414
# Minibatch: 301 | Cost:    74777.812
# Minibatch: 321 | Cost:    72454.250
# Minibatch: 341 | Cost:    65079.070
# Minibatch: 361 | Cost:    74612.953
# Minibatch: 381 | Cost:    71250.086
# Minibatch: 401 | Cost:    73170.734
# Minibatch: 421 | Cost:    71345.461
# Minibatch: 441 | Cost:    68788.977
# Minibatch: 461 | Cost:    68143.922
# Minibatch: 481 | Cost:    65481.555
# Epoch:     001 | AvgCost: 3127125.002
# Minibatch: 001 | Cost:    43241.824
# Minibatch: 021 | Cost:    3506.627
# Minibatch: 041 | Cost:    3613.996
# Minibatch: 061 | Cost:    2120.204
# Minibatch: 081 | Cost:    3956.991
# Minibatch: 101 | Cost:    2022.733
# Minibatch: 121 | Cost:    3118.479
# Minibatch: 141 | Cost:    2117.033
# Minibatch: 161 | Cost:    2006.041
# Minibatch: 181 | Cost:    1636.174
# Minibatch: 201 | Cost:    1866.406
# Minibatch: 221 | Cost:    1640.059
# Minibatch: 241 | Cost:    2643.241
# Minibatch: 261 | Cost:    2272.840
# Minibatch: 281 | Cost:    2169.457
# Minibatch: 301 | Cost:    1791.506
# Minibatch: 321 | Cost:    2418.943
# Minibatch: 341 | Cost:    1938.759
# Minibatch: 361 | Cost:    3105.446
# Minibatch: 381 | Cost:    63535.574
# Minibatch: 401 | Cost:    1648.552
# Minibatch: 421 | Cost:    2303.027
# Minibatch: 441 | Cost:    2133.242
# Minibatch: 461 | Cost:    5295.601
# Minibatch: 481 | Cost:    2894.516
# Epoch:     002 | AvgCost: 2882038.785
# Minibatch: 001 | Cost:    5077.771
# Minibatch: 021 | Cost:    37989.129
# Minibatch: 041 | Cost:    44777.492
# Minibatch: 061 | Cost:    39785.477
# Minibatch: 081 | Cost:    9243.838
# Minibatch: 101 | Cost:    4228.071
# Minibatch: 121 | Cost:    1949.834
# Minibatch: 141 | Cost:    4985.145
# Minibatch: 161 | Cost:    4466.591
# Minibatch: 181 | Cost:    2414.652
# Minibatch: 201 | Cost:    2155.304
# Minibatch: 221 | Cost:    880.526
# Minibatch: 241 | Cost:    827.345
# Minibatch: 261 | Cost:    2395.727
# Minibatch: 281 | Cost:    2188.344
# Minibatch: 301 | Cost:    1253.734
# Minibatch: 321 | Cost:    1327.053
# Minibatch: 341 | Cost:    2369.773
# Minibatch: 361 | Cost:    2624.719
# Minibatch: 381 | Cost:    2595.381
# Minibatch: 401 | Cost:    3504.268
# Minibatch: 421 | Cost:    2226.735
# Minibatch: 441 | Cost:    1457.241
# Minibatch: 461 | Cost:    1503.255
# Minibatch: 481 | Cost:    3113.810
# Epoch:     003 | AvgCost: 1746208.956
# Minibatch: 001 | Cost:    272740.281
# Minibatch: 021 | Cost:    17474.398
# Minibatch: 041 | Cost:    14506.486
# Minibatch: 061 | Cost:    728.034
# Minibatch: 081 | Cost:    319.117
# Minibatch: 101 | Cost:    237.701
# Minibatch: 121 | Cost:    204.309
# Minibatch: 141 | Cost:    195.628
# Minibatch: 161 | Cost:    195.458
# Minibatch: 181 | Cost:    196.480
# Minibatch: 201 | Cost:    196.513
# Minibatch: 221 | Cost:    196.651
# Minibatch: 241 | Cost:    211.571
# Minibatch: 261 | Cost:    196.988
# Minibatch: 281 | Cost:    193.517
# Minibatch: 301 | Cost:    191.734
# Minibatch: 321 | Cost:    236.968
# Minibatch: 341 | Cost:    185.610
# Minibatch: 361 | Cost:    197.908
# Minibatch: 381 | Cost:    181.647
# Minibatch: 401 | Cost:    217.455
# Minibatch: 421 | Cost:    174.103
# Minibatch: 441 | Cost:    188.637
# Minibatch: 461 | Cost:    188.657
# Minibatch: 481 | Cost:    203.306
# Epoch:     004 | AvgCost: 295456.494
# Minibatch: 001 | Cost:    50662.781
# Minibatch: 021 | Cost:    20173.857
# Minibatch: 041 | Cost:    14556.672
# Minibatch: 061 | Cost:    10937.193
# Minibatch: 081 | Cost:    8969.609
# Minibatch: 101 | Cost:    9976.276
# Minibatch: 121 | Cost:    8063.404
# Minibatch: 141 | Cost:    6510.766
# Minibatch: 161 | Cost:    7241.803
# Minibatch: 181 | Cost:    6882.504
# Minibatch: 201 | Cost:    6681.445
# Minibatch: 221 | Cost:    6230.750
# Minibatch: 241 | Cost:    6527.922
# Minibatch: 261 | Cost:    6785.780
# Minibatch: 281 | Cost:    5013.278
# Minibatch: 301 | Cost:    6392.433
# Minibatch: 321 | Cost:    8004.364
# Minibatch: 341 | Cost:    7165.601
# Minibatch: 361 | Cost:    6464.299
# Minibatch: 381 | Cost:    6455.637
# Minibatch: 401 | Cost:    6030.081
# Minibatch: 421 | Cost:    7239.194
# Minibatch: 441 | Cost:    8112.413
# Minibatch: 461 | Cost:    7327.677
# Minibatch: 481 | Cost:    11153.169
# Epoch:     005 | AvgCost: 4155126.122
# Minibatch: 001 | Cost:    10320.741
# Minibatch: 021 | Cost:    10225.774
# Minibatch: 041 | Cost:    10123.686
# Minibatch: 061 | Cost:    8962.448
# Minibatch: 081 | Cost:    9106.453
# Minibatch: 101 | Cost:    10961.703
# Minibatch: 121 | Cost:    9580.537
# Minibatch: 141 | Cost:    9461.154
# Minibatch: 161 | Cost:    9522.653
# Minibatch: 181 | Cost:    9143.682
# Minibatch: 201 | Cost:    10417.336
# Minibatch: 221 | Cost:    9772.214
# Minibatch: 241 | Cost:    10021.327
# Minibatch: 261 | Cost:    9467.727
# Minibatch: 281 | Cost:    9091.354
# Minibatch: 301 | Cost:    9413.576
# Minibatch: 321 | Cost:    9512.787
# Minibatch: 341 | Cost:    9144.889
# Minibatch: 361 | Cost:    9790.962
# Minibatch: 381 | Cost:    11669.709
# Minibatch: 401 | Cost:    11464.451
# Minibatch: 421 | Cost:    11336.676
# Minibatch: 441 | Cost:    10958.622
# Minibatch: 461 | Cost:    10107.854
# Minibatch: 481 | Cost:    9623.873
# Epoch:     006 | AvgCost: 1566069.269
# Minibatch: 001 | Cost:    331904.156
# Minibatch: 021 | Cost:    83083.398
# Minibatch: 041 | Cost:    78381.766
# Minibatch: 061 | Cost:    80921.516
# Minibatch: 081 | Cost:    82917.625
# Minibatch: 101 | Cost:    82215.250
# Minibatch: 121 | Cost:    82241.609
# Minibatch: 141 | Cost:    81955.867
# Minibatch: 161 | Cost:    79945.953
# Minibatch: 181 | Cost:    80812.672
# Minibatch: 201 | Cost:    80951.586
# Minibatch: 221 | Cost:    84383.516
# Minibatch: 241 | Cost:    80398.820
# Minibatch: 261 | Cost:    81703.812
# Minibatch: 281 | Cost:    78063.578
# Minibatch: 301 | Cost:    82815.641
# Minibatch: 321 | Cost:    78208.250
# Minibatch: 341 | Cost:    77823.531
# Minibatch: 361 | Cost:    75555.188
# Minibatch: 381 | Cost:    76714.797
# Minibatch: 401 | Cost:    76410.453
# Minibatch: 421 | Cost:    77321.062
# Minibatch: 441 | Cost:    78142.172
# Minibatch: 461 | Cost:    79788.539
# Minibatch: 481 | Cost:    82605.266
# Epoch:     007 | AvgCost: 5773085.088
# Minibatch: 001 | Cost:    172234.344
# Minibatch: 021 | Cost:    97120.172
# Minibatch: 041 | Cost:    58535.250
# Minibatch: 061 | Cost:    29487.469
# Minibatch: 081 | Cost:    17240.328
# Minibatch: 101 | Cost:    18178.535
# Minibatch: 121 | Cost:    46640.410
# Minibatch: 141 | Cost:    30474.207
# Minibatch: 161 | Cost:    42507.902
# Minibatch: 181 | Cost:    41192.855
# Minibatch: 201 | Cost:    23411.328
# Minibatch: 221 | Cost:    33436.695
# Minibatch: 241 | Cost:    12749.273
# Minibatch: 261 | Cost:    183792.500
# Minibatch: 281 | Cost:    32261.059
# Minibatch: 301 | Cost:    31219.787
# Minibatch: 321 | Cost:    26559.557
# Minibatch: 341 | Cost:    23423.057
# Minibatch: 361 | Cost:    14706.406
# Minibatch: 381 | Cost:    12680.822
# Minibatch: 401 | Cost:    75802.086
# Minibatch: 421 | Cost:    25409.746
# Minibatch: 441 | Cost:    23023.828
# Minibatch: 461 | Cost:    19140.400
# Minibatch: 481 | Cost:    12500.562
# Epoch:     008 | AvgCost: 1808839.901
# Minibatch: 001 | Cost:    197409.531
# Minibatch: 021 | Cost:    157035.344
# Minibatch: 041 | Cost:    151335.703
# Minibatch: 061 | Cost:    164209.844
# Minibatch: 081 | Cost:    160582.703
# Minibatch: 101 | Cost:    168393.656
# Minibatch: 121 | Cost:    163440.250
# Minibatch: 141 | Cost:    136141.969
# Minibatch: 161 | Cost:    155077.016
# Minibatch: 181 | Cost:    147453.938
# Minibatch: 201 | Cost:    193886.203
# Minibatch: 221 | Cost:    156796.016
# Minibatch: 241 | Cost:    151243.281
# Minibatch: 261 | Cost:    156071.375
# Minibatch: 281 | Cost:    150699.406
# Minibatch: 301 | Cost:    174286.938
# Minibatch: 321 | Cost:    159145.844
# Minibatch: 341 | Cost:    149336.156
# Minibatch: 361 | Cost:    151846.531
# Minibatch: 381 | Cost:    158621.875
# Minibatch: 401 | Cost:    156688.109
# Minibatch: 421 | Cost:    192524.203
# Minibatch: 441 | Cost:    151098.594
# Minibatch: 461 | Cost:    145578.297
# Minibatch: 481 | Cost:    149727.641
# Epoch:     009 | AvgCost: 1568027.272
# Minibatch: 001 | Cost:    51172.203
# Minibatch: 021 | Cost:    36821.715
# Minibatch: 041 | Cost:    36300.324
# Minibatch: 061 | Cost:    33728.707
# Minibatch: 081 | Cost:    32065.824
# Minibatch: 101 | Cost:    30712.447
# Minibatch: 121 | Cost:    33809.434
# Minibatch: 141 | Cost:    29693.254
# Minibatch: 161 | Cost:    32112.256
# Minibatch: 181 | Cost:    29017.453
# Minibatch: 201 | Cost:    27457.543
# Minibatch: 221 | Cost:    26564.025
# Minibatch: 241 | Cost:    26814.553
# Minibatch: 261 | Cost:    28894.426
# Minibatch: 281 | Cost:    27727.475
# Minibatch: 301 | Cost:    26793.416
# Minibatch: 321 | Cost:    26915.412
# Minibatch: 341 | Cost:    28366.178
# Minibatch: 361 | Cost:    26456.598
# Minibatch: 381 | Cost:    28968.975
# Minibatch: 401 | Cost:    26615.584
# Minibatch: 421 | Cost:    25987.012
# Minibatch: 441 | Cost:    26841.105
# Minibatch: 461 | Cost:    26120.824
# Minibatch: 481 | Cost:    26276.994
# Epoch:     010 | AvgCost: 1578573.900
# Minibatch: 001 | Cost:    54140.238
# Minibatch: 021 | Cost:    3106.795
# Minibatch: 041 | Cost:    2329.188
# Minibatch: 061 | Cost:    1970.133
# Minibatch: 081 | Cost:    4836.046
# Minibatch: 101 | Cost:    1656.412
# Minibatch: 121 | Cost:    1753.296
# Minibatch: 141 | Cost:    2573.039
# Minibatch: 161 | Cost:    6361.961
# Minibatch: 181 | Cost:    2112.089
# Minibatch: 201 | Cost:    760.918
# Minibatch: 221 | Cost:    1556.579
# Minibatch: 241 | Cost:    1684.386
# Minibatch: 261 | Cost:    2547.796
# Minibatch: 281 | Cost:    3317.884
# Minibatch: 301 | Cost:    1815.534
# Minibatch: 321 | Cost:    1824.482
# Minibatch: 341 | Cost:    2188.736
# Minibatch: 361 | Cost:    2296.063
# Minibatch: 381 | Cost:    2121.635
# Minibatch: 401 | Cost:    2380.458
# Minibatch: 421 | Cost:    1629.268
# Minibatch: 441 | Cost:    1972.914
# Minibatch: 461 | Cost:    2357.583
# Minibatch: 481 | Cost:    2922.241
# Epoch:     011 | AvgCost: 3743355.282
# Minibatch: 001 | Cost:    135135.469
# Minibatch: 021 | Cost:    9699.516
# Minibatch: 041 | Cost:    11258.355
# Minibatch: 061 | Cost:    12494.938
# Minibatch: 081 | Cost:    12365.880
# Minibatch: 101 | Cost:    9586.529
# Minibatch: 121 | Cost:    28814.725
# Minibatch: 141 | Cost:    12143.430
# Minibatch: 161 | Cost:    11749.812
# Minibatch: 181 | Cost:    12668.639
# Minibatch: 201 | Cost:    13416.310
# Minibatch: 221 | Cost:    12816.638
# Minibatch: 241 | Cost:    12908.625
# Minibatch: 261 | Cost:    12473.984
# Minibatch: 281 | Cost:    9853.308
# Minibatch: 301 | Cost:    10826.344
# Minibatch: 321 | Cost:    12256.930
# Minibatch: 341 | Cost:    12692.074
# Minibatch: 361 | Cost:    12027.552
# Minibatch: 381 | Cost:    12699.130
# Minibatch: 401 | Cost:    17019.656
# Minibatch: 421 | Cost:    13091.447
# Minibatch: 441 | Cost:    12739.282
# Minibatch: 461 | Cost:    11216.310
# Minibatch: 481 | Cost:    12144.084
# Epoch:     012 | AvgCost: 4020049.027
# Minibatch: 001 | Cost:    116648.789
# Minibatch: 021 | Cost:    74173.469
# Minibatch: 041 | Cost:    72950.727
# Minibatch: 061 | Cost:    69303.531
# Minibatch: 081 | Cost:    69948.672
# Minibatch: 101 | Cost:    71785.883
# Minibatch: 121 | Cost:    59725.133
# Minibatch: 141 | Cost:    62603.289
# Minibatch: 161 | Cost:    79416.453
# Minibatch: 181 | Cost:    65535.020
# Minibatch: 201 | Cost:    65769.820
# Minibatch: 221 | Cost:    72031.953
# Minibatch: 241 | Cost:    67413.625
# Minibatch: 261 | Cost:    65447.230
# Minibatch: 281 | Cost:    64327.238
# Minibatch: 301 | Cost:    68118.359
# Minibatch: 321 | Cost:    75617.070
# Minibatch: 341 | Cost:    61479.520
# Minibatch: 361 | Cost:    66183.797
# Minibatch: 381 | Cost:    68991.047
# Minibatch: 401 | Cost:    72550.305
# Minibatch: 421 | Cost:    67478.977
# Minibatch: 441 | Cost:    99158.633
# Minibatch: 461 | Cost:    57238.492
# Minibatch: 481 | Cost:    62214.656
# Epoch:     013 | AvgCost: 1561264.978
# Minibatch: 001 | Cost:    452295.812
# Minibatch: 021 | Cost:    89566.305
# Minibatch: 041 | Cost:    62864.148
# Minibatch: 061 | Cost:    55296.156
# Minibatch: 081 | Cost:    46479.551
# Minibatch: 101 | Cost:    49306.203
# Minibatch: 121 | Cost:    47198.887
# Minibatch: 141 | Cost:    45506.863
# Minibatch: 161 | Cost:    43720.957
# Minibatch: 181 | Cost:    139666.422
# Minibatch: 201 | Cost:    51959.352
# Minibatch: 221 | Cost:    48096.344
# Minibatch: 241 | Cost:    45976.723
# Minibatch: 261 | Cost:    45064.438
# Minibatch: 281 | Cost:    49675.477
# Minibatch: 301 | Cost:    43014.438
# Minibatch: 321 | Cost:    42751.121
# Minibatch: 341 | Cost:    43105.883
# Minibatch: 361 | Cost:    54130.750
# Minibatch: 381 | Cost:    49278.828
# Minibatch: 401 | Cost:    47757.531
# Minibatch: 421 | Cost:    46535.809
# Minibatch: 441 | Cost:    43856.074
# Minibatch: 461 | Cost:    42259.375
# Minibatch: 481 | Cost:    41214.180
# Epoch:     014 | AvgCost: 1035123.474
# Minibatch: 001 | Cost:    175864.547
# Minibatch: 021 | Cost:    64129.367
# Minibatch: 041 | Cost:    61616.363
# Minibatch: 061 | Cost:    62578.293
# Minibatch: 081 | Cost:    59842.914
# Minibatch: 101 | Cost:    60163.281
# Minibatch: 121 | Cost:    60868.711
# Minibatch: 141 | Cost:    60671.957
# Minibatch: 161 | Cost:    97353.469
# Minibatch: 181 | Cost:    59565.211
# Minibatch: 201 | Cost:    60837.664
# Minibatch: 221 | Cost:    58446.387
# Minibatch: 241 | Cost:    59625.926
# Minibatch: 261 | Cost:    77906.680
# Minibatch: 281 | Cost:    59258.855
# Minibatch: 301 | Cost:    61230.301
# Minibatch: 321 | Cost:    60924.668
# Minibatch: 341 | Cost:    59695.148
# Minibatch: 361 | Cost:    59948.742
# Minibatch: 381 | Cost:    60131.070
# Minibatch: 401 | Cost:    60089.320
# Minibatch: 421 | Cost:    61709.750
# Minibatch: 441 | Cost:    59648.918
# Minibatch: 461 | Cost:    60637.562
# Minibatch: 481 | Cost:    59657.906
# Epoch:     015 | AvgCost: 4706133.222
# Minibatch: 001 | Cost:    20258.277
# Minibatch: 021 | Cost:    27024.150
# Minibatch: 041 | Cost:    10825.592
# Minibatch: 061 | Cost:    10041.320
# Minibatch: 081 | Cost:    8589.607
# Minibatch: 101 | Cost:    6610.308
# Minibatch: 121 | Cost:    9962.974
# Minibatch: 141 | Cost:    6565.701
# Minibatch: 161 | Cost:    24140.684
# Minibatch: 181 | Cost:    6518.358
# Minibatch: 201 | Cost:    9086.248
# Minibatch: 221 | Cost:    6320.761
# Minibatch: 241 | Cost:    12328.323
# Minibatch: 261 | Cost:    6603.780
# Minibatch: 281 | Cost:    21394.822
# Minibatch: 301 | Cost:    6551.748
# Minibatch: 321 | Cost:    39707.871
# Minibatch: 341 | Cost:    10612.385
# Minibatch: 361 | Cost:    6489.795
# Minibatch: 381 | Cost:    14715.787
# Minibatch: 401 | Cost:    6542.615
# Minibatch: 421 | Cost:    6693.858
# Minibatch: 441 | Cost:    9171.104
# Minibatch: 461 | Cost:    14025.938
# Minibatch: 481 | Cost:    6010.905
# Epoch:     016 | AvgCost: 4180565.136
# Minibatch: 001 | Cost:    153668.969
# Minibatch: 021 | Cost:    100110.023
# Minibatch: 041 | Cost:    97260.953
# Minibatch: 061 | Cost:    94681.750
# Minibatch: 081 | Cost:    95143.750
# Minibatch: 101 | Cost:    94985.977
# Minibatch: 121 | Cost:    104929.828
# Minibatch: 141 | Cost:    96430.289
# Minibatch: 161 | Cost:    95242.016
# Minibatch: 181 | Cost:    112819.922
# Minibatch: 201 | Cost:    99419.375
# Minibatch: 221 | Cost:    99386.953
# Minibatch: 241 | Cost:    113651.375
# Minibatch: 261 | Cost:    102831.773
# Minibatch: 281 | Cost:    97116.453
# Minibatch: 301 | Cost:    111396.047
# Minibatch: 321 | Cost:    97985.469
# Minibatch: 341 | Cost:    125608.703
# Minibatch: 361 | Cost:    100241.000
# Minibatch: 381 | Cost:    96575.953
# Minibatch: 401 | Cost:    95633.922
# Minibatch: 421 | Cost:    109965.938
# Minibatch: 441 | Cost:    96552.359
# Minibatch: 461 | Cost:    101634.234
# Minibatch: 481 | Cost:    96423.250
# Epoch:     017 | AvgCost: 2552076.841
# Minibatch: 001 | Cost:    91037.602
# Minibatch: 021 | Cost:    6730.211
# Minibatch: 041 | Cost:    1052.863
# Minibatch: 061 | Cost:    9.093
# Minibatch: 081 | Cost:    0.979
# Minibatch: 101 | Cost:    0.389
# Minibatch: 121 | Cost:    0.356
# Minibatch: 141 | Cost:    0.357
# Minibatch: 161 | Cost:    9.303
# Minibatch: 181 | Cost:    381.623
# Minibatch: 201 | Cost:    1.457
# Minibatch: 221 | Cost:    0.368
# Minibatch: 241 | Cost:    0.369
# Minibatch: 261 | Cost:    0.376
# Minibatch: 281 | Cost:    0.562
# Minibatch: 301 | Cost:    581.622
# Minibatch: 321 | Cost:    180.151
# Minibatch: 341 | Cost:    1.420
# Minibatch: 361 | Cost:    4.190
# Minibatch: 381 | Cost:    36.058
# Minibatch: 401 | Cost:    23.969
# Minibatch: 421 | Cost:    124.627
# Minibatch: 441 | Cost:    9.462
# Minibatch: 461 | Cost:    22.241
# Minibatch: 481 | Cost:    74.378
# Epoch:     018 | AvgCost: 17047.674
# Minibatch: 001 | Cost:    81022.734
# Minibatch: 021 | Cost:    18531.014
# Minibatch: 041 | Cost:    19265.666
# Minibatch: 061 | Cost:    14310.692
# Minibatch: 081 | Cost:    15635.034
# Minibatch: 101 | Cost:    17403.924
# Minibatch: 121 | Cost:    14903.857
# Minibatch: 141 | Cost:    15155.025
# Minibatch: 161 | Cost:    13514.672
# Minibatch: 181 | Cost:    13694.747
# Minibatch: 201 | Cost:    14488.506
# Minibatch: 221 | Cost:    20218.959
# Minibatch: 241 | Cost:    13760.570
# Minibatch: 261 | Cost:    13151.969
# Minibatch: 281 | Cost:    14606.305
# Minibatch: 301 | Cost:    13580.131
# Minibatch: 321 | Cost:    13026.143
# Minibatch: 341 | Cost:    12976.168
# Minibatch: 361 | Cost:    13280.713
# Minibatch: 381 | Cost:    14668.208
# Minibatch: 401 | Cost:    12871.278
# Minibatch: 421 | Cost:    12797.850
# Minibatch: 441 | Cost:    13169.997
# Minibatch: 461 | Cost:    14513.352
# Minibatch: 481 | Cost:    13407.258
# Epoch:     019 | AvgCost: 2047381.527
# Minibatch: 001 | Cost:    119773.312
# Minibatch: 021 | Cost:    15081.261
# Minibatch: 041 | Cost:    14244.981
# Minibatch: 061 | Cost:    13624.662
# Minibatch: 081 | Cost:    13655.031
# Minibatch: 101 | Cost:    12596.049
# Minibatch: 121 | Cost:    12369.682
# Minibatch: 141 | Cost:    13968.234
# Minibatch: 161 | Cost:    13420.854
# Minibatch: 181 | Cost:    13619.997
# Minibatch: 201 | Cost:    14406.006
# Minibatch: 221 | Cost:    12779.432
# Minibatch: 241 | Cost:    12936.627
# Minibatch: 261 | Cost:    13236.498
# Minibatch: 281 | Cost:    13381.107
# Minibatch: 301 | Cost:    13167.023
# Minibatch: 321 | Cost:    13331.916
# Minibatch: 341 | Cost:    13672.283
# Minibatch: 361 | Cost:    13356.120
# Minibatch: 381 | Cost:    13325.998
# Minibatch: 401 | Cost:    13278.463
# Minibatch: 421 | Cost:    13897.953
# Minibatch: 441 | Cost:    13654.080
# Minibatch: 461 | Cost:    13145.745
# Minibatch: 481 | Cost:    13507.352
# Epoch:     020 | AvgCost: 880330.467
# Minibatch: 001 | Cost:    168797.594
# Minibatch: 021 | Cost:    20200.717
# Minibatch: 041 | Cost:    4043.546
# Minibatch: 061 | Cost:    2187.718
# Minibatch: 081 | Cost:    2714.322
# Minibatch: 101 | Cost:    1988.632
# Minibatch: 121 | Cost:    1418.113
# Minibatch: 141 | Cost:    2094.606
# Minibatch: 161 | Cost:    2606.170
# Minibatch: 181 | Cost:    844.721
# Minibatch: 201 | Cost:    603.219
# Minibatch: 221 | Cost:    1380.565
# Minibatch: 241 | Cost:    2492.098
# Minibatch: 261 | Cost:    1893.795
# Minibatch: 281 | Cost:    5226.908
# Minibatch: 301 | Cost:    3518.192
# Minibatch: 321 | Cost:    1842.542
# Minibatch: 341 | Cost:    1285.300
# Minibatch: 361 | Cost:    2634.673
# Minibatch: 381 | Cost:    5144.192
# Minibatch: 401 | Cost:    2238.329
# Minibatch: 421 | Cost:    2647.862
# Minibatch: 441 | Cost:    42610.211
# Minibatch: 461 | Cost:    766.526
# Minibatch: 481 | Cost:    1780.808
# Epoch:     021 | AvgCost: 467688.019
# Minibatch: 001 | Cost:    90441.570
# Minibatch: 021 | Cost:    106702.023
# Minibatch: 041 | Cost:    108401.336
# Minibatch: 061 | Cost:    108847.859
# Minibatch: 081 | Cost:    108520.648
# Minibatch: 101 | Cost:    109826.953
# Minibatch: 121 | Cost:    110514.898
# Minibatch: 141 | Cost:    109078.164
# Minibatch: 161 | Cost:    108162.297
# Minibatch: 181 | Cost:    110519.250
# Minibatch: 201 | Cost:    108585.359
# Minibatch: 221 | Cost:    109277.312
# Minibatch: 241 | Cost:    115403.273
# Minibatch: 261 | Cost:    109168.828
# Minibatch: 281 | Cost:    109498.297
# Minibatch: 301 | Cost:    108885.602
# Minibatch: 321 | Cost:    110625.672
# Minibatch: 341 | Cost:    107387.422
# Minibatch: 361 | Cost:    108759.523
# Minibatch: 381 | Cost:    108543.578
# Minibatch: 401 | Cost:    109126.602
# Minibatch: 421 | Cost:    108810.109
# Minibatch: 441 | Cost:    108751.273
# Minibatch: 461 | Cost:    108912.875
# Minibatch: 481 | Cost:    108822.625
# Epoch:     022 | AvgCost: 4486431.775
# Minibatch: 001 | Cost:    76466.102
# Minibatch: 021 | Cost:    5778.875
# Minibatch: 041 | Cost:    11104.761
# Minibatch: 061 | Cost:    3861.254
# Minibatch: 081 | Cost:    3760.454
# Minibatch: 101 | Cost:    3314.607
# Minibatch: 121 | Cost:    2779.146
# Minibatch: 141 | Cost:    3104.528
# Minibatch: 161 | Cost:    2583.195
# Minibatch: 181 | Cost:    6177.725
# Minibatch: 201 | Cost:    3100.608
# Minibatch: 221 | Cost:    3595.146
# Minibatch: 241 | Cost:    3047.868
# Minibatch: 261 | Cost:    3339.763
# Minibatch: 281 | Cost:    3102.561
# Minibatch: 301 | Cost:    3046.300
# Minibatch: 321 | Cost:    3068.205
# Minibatch: 341 | Cost:    13478.314
# Minibatch: 361 | Cost:    6866.923
# Minibatch: 381 | Cost:    6400.657
# Minibatch: 401 | Cost:    5767.673
# Minibatch: 421 | Cost:    3366.773
# Minibatch: 441 | Cost:    2959.053
# Minibatch: 461 | Cost:    2725.945
# Minibatch: 481 | Cost:    5738.098
# Epoch:     023 | AvgCost: 1090905.326
# Minibatch: 001 | Cost:    285746.812
# Minibatch: 021 | Cost:    16123.686
# Minibatch: 041 | Cost:    16862.305
# Minibatch: 061 | Cost:    16593.549
# Minibatch: 081 | Cost:    16847.652
# Minibatch: 101 | Cost:    17217.996
# Minibatch: 121 | Cost:    16863.449
# Minibatch: 141 | Cost:    16526.918
# Minibatch: 161 | Cost:    16976.941
# Minibatch: 181 | Cost:    17005.020
# Minibatch: 201 | Cost:    17730.488
# Minibatch: 221 | Cost:    18306.891
# Minibatch: 241 | Cost:    17932.596
# Minibatch: 261 | Cost:    16550.301
# Minibatch: 281 | Cost:    19265.695
# Minibatch: 301 | Cost:    16704.973
# Minibatch: 321 | Cost:    18614.199
# Minibatch: 341 | Cost:    16395.885
# Minibatch: 361 | Cost:    16655.131
# Minibatch: 381 | Cost:    16853.037
# Minibatch: 401 | Cost:    16528.555
# Minibatch: 421 | Cost:    17243.402
# Minibatch: 441 | Cost:    17080.676
# Minibatch: 461 | Cost:    16524.053
# Minibatch: 481 | Cost:    16656.523
# Epoch:     024 | AvgCost: 849164.628
# Minibatch: 001 | Cost:    62980.594
# Minibatch: 021 | Cost:    12259.030
# Minibatch: 041 | Cost:    10125.537
# Minibatch: 061 | Cost:    7820.477
# Minibatch: 081 | Cost:    7788.096
# Minibatch: 101 | Cost:    8562.119
# Minibatch: 121 | Cost:    7723.775
# Minibatch: 141 | Cost:    7724.075
# Minibatch: 161 | Cost:    19872.498
# Minibatch: 181 | Cost:    7032.853
# Minibatch: 201 | Cost:    7331.897
# Minibatch: 221 | Cost:    8128.830
# Minibatch: 241 | Cost:    12671.338
# Minibatch: 261 | Cost:    7987.606
# Minibatch: 281 | Cost:    6792.876
# Minibatch: 301 | Cost:    6742.870
# Minibatch: 321 | Cost:    8014.352
# Minibatch: 341 | Cost:    7908.514
# Minibatch: 361 | Cost:    8302.143
# Minibatch: 381 | Cost:    7845.183
# Minibatch: 401 | Cost:    7482.315
# Minibatch: 421 | Cost:    8990.185
# Minibatch: 441 | Cost:    8873.511
# Minibatch: 461 | Cost:    10978.130
# Minibatch: 481 | Cost:    6757.158
# Epoch:     025 | AvgCost: 1462659.975
# Minibatch: 001 | Cost:    331618.938
# Minibatch: 021 | Cost:    3786.603
# Minibatch: 041 | Cost:    4053.833
# Minibatch: 061 | Cost:    5491.913
# Minibatch: 081 | Cost:    3942.774
# Minibatch: 101 | Cost:    3437.193
# Minibatch: 121 | Cost:    4223.049
# Minibatch: 141 | Cost:    3429.390
# Minibatch: 161 | Cost:    3536.400
# Minibatch: 181 | Cost:    3238.843
# Minibatch: 201 | Cost:    3212.090
# Minibatch: 221 | Cost:    3230.272
# Minibatch: 241 | Cost:    3023.482
# Minibatch: 261 | Cost:    3340.018
# Minibatch: 281 | Cost:    3138.999
# Minibatch: 301 | Cost:    5025.419
# Minibatch: 321 | Cost:    3274.515
# Minibatch: 341 | Cost:    3476.370
# Minibatch: 361 | Cost:    3957.659
# Minibatch: 381 | Cost:    3186.056
# Minibatch: 401 | Cost:    3416.464
# Minibatch: 421 | Cost:    2805.893
# Minibatch: 441 | Cost:    3297.293
# Minibatch: 461 | Cost:    3480.713
# Minibatch: 481 | Cost:    3025.620
# Epoch:     026 | AvgCost: 2987356.412
# Minibatch: 001 | Cost:    282992.344
# Minibatch: 021 | Cost:    51632.000
# Minibatch: 041 | Cost:    49100.047
# Minibatch: 061 | Cost:    48145.262
# Minibatch: 081 | Cost:    45267.270
# Minibatch: 101 | Cost:    45984.352
# Minibatch: 121 | Cost:    41679.074
# Minibatch: 141 | Cost:    39407.793
# Minibatch: 161 | Cost:    39612.707
# Minibatch: 181 | Cost:    42378.652
# Minibatch: 201 | Cost:    47217.148
# Minibatch: 221 | Cost:    44356.195
# Minibatch: 241 | Cost:    43782.867
# Minibatch: 261 | Cost:    44796.105
# Minibatch: 281 | Cost:    41866.840
# Minibatch: 301 | Cost:    42552.078
# Minibatch: 321 | Cost:    40168.969
# Minibatch: 341 | Cost:    43908.207
# Minibatch: 361 | Cost:    39407.051
# Minibatch: 381 | Cost:    42608.895
# Minibatch: 401 | Cost:    50478.957
# Minibatch: 421 | Cost:    46362.805
# Minibatch: 441 | Cost:    46219.766
# Minibatch: 461 | Cost:    38664.215
# Minibatch: 481 | Cost:    45349.551
# Epoch:     027 | AvgCost: 4243907.669
# Minibatch: 001 | Cost:    113955.898
# Minibatch: 021 | Cost:    85888.945
# Minibatch: 041 | Cost:    87973.484
# Minibatch: 061 | Cost:    86474.586
# Minibatch: 081 | Cost:    88850.680
# Minibatch: 101 | Cost:    89122.922
# Minibatch: 121 | Cost:    88341.078
# Minibatch: 141 | Cost:    87684.688
# Minibatch: 161 | Cost:    86363.391
# Minibatch: 181 | Cost:    89110.789
# Minibatch: 201 | Cost:    88538.547
# Minibatch: 221 | Cost:    85771.672
# Minibatch: 241 | Cost:    85556.148
# Minibatch: 261 | Cost:    85895.609
# Minibatch: 281 | Cost:    87018.055
# Minibatch: 301 | Cost:    86263.969
# Minibatch: 321 | Cost:    86110.602
# Minibatch: 341 | Cost:    85610.164
# Minibatch: 361 | Cost:    90341.812
# Minibatch: 381 | Cost:    87404.461
# Minibatch: 401 | Cost:    84789.609
# Minibatch: 421 | Cost:    84328.977
# Minibatch: 441 | Cost:    88988.359
# Minibatch: 461 | Cost:    86327.414
# Minibatch: 481 | Cost:    84514.789
# Epoch:     028 | AvgCost: 4811611.687
# Minibatch: 001 | Cost:    611358.125
# Minibatch: 021 | Cost:    54183.531
# Minibatch: 041 | Cost:    40764.230
# Minibatch: 061 | Cost:    36184.668
# Minibatch: 081 | Cost:    48092.008
# Minibatch: 101 | Cost:    38465.250
# Minibatch: 121 | Cost:    38340.012
# Minibatch: 141 | Cost:    37694.074
# Minibatch: 161 | Cost:    36092.613
# Minibatch: 181 | Cost:    33642.617
# Minibatch: 201 | Cost:    36252.672
# Minibatch: 221 | Cost:    33754.520
# Minibatch: 241 | Cost:    38115.160
# Minibatch: 261 | Cost:    97472.656
# Minibatch: 281 | Cost:    42681.477
# Minibatch: 301 | Cost:    41532.441
# Minibatch: 321 | Cost:    43548.195
# Minibatch: 341 | Cost:    38249.324
# Minibatch: 361 | Cost:    36487.691
# Minibatch: 381 | Cost:    35979.277
# Minibatch: 401 | Cost:    43546.250
# Minibatch: 421 | Cost:    38370.695
# Minibatch: 441 | Cost:    35752.215
# Minibatch: 461 | Cost:    36828.133
# Minibatch: 481 | Cost:    41460.336
# Epoch:     029 | AvgCost: 3451269.278
# Minibatch: 001 | Cost:    57272.488
# Minibatch: 021 | Cost:    11590.895
# Minibatch: 041 | Cost:    9469.795
# Minibatch: 061 | Cost:    9970.833
# Minibatch: 081 | Cost:    9909.865
# Minibatch: 101 | Cost:    9337.316
# Minibatch: 121 | Cost:    10175.217
# Minibatch: 141 | Cost:    9586.021
# Minibatch: 161 | Cost:    17597.861
# Minibatch: 181 | Cost:    9695.669
# Minibatch: 201 | Cost:    9296.611
# Minibatch: 221 | Cost:    14645.935
# Minibatch: 241 | Cost:    10777.155
# Minibatch: 261 | Cost:    10411.961
# Minibatch: 281 | Cost:    10729.611
# Minibatch: 301 | Cost:    9912.589
# Minibatch: 321 | Cost:    9598.857
# Minibatch: 341 | Cost:    9666.783
# Minibatch: 361 | Cost:    13060.466
# Minibatch: 381 | Cost:    9519.094
# Minibatch: 401 | Cost:    10197.327
# Minibatch: 421 | Cost:    9890.896
# Minibatch: 441 | Cost:    12619.044
# Minibatch: 461 | Cost:    9432.393
# Minibatch: 481 | Cost:    9650.061
# Epoch:     030 | AvgCost: 2023645.923
# Minibatch: 001 | Cost:    131504.516
# Minibatch: 021 | Cost:    23088.590
# Minibatch: 041 | Cost:    23829.035
# Minibatch: 061 | Cost:    21899.066
# Minibatch: 081 | Cost:    23814.766
# Minibatch: 101 | Cost:    19487.652
# Minibatch: 121 | Cost:    22828.805
# Minibatch: 141 | Cost:    23742.551
# Minibatch: 161 | Cost:    24014.086
# Minibatch: 181 | Cost:    22766.598
# Minibatch: 201 | Cost:    24261.926
# Minibatch: 221 | Cost:    23825.941
# Minibatch: 241 | Cost:    21417.881
# Minibatch: 261 | Cost:    22572.283
# Minibatch: 281 | Cost:    23279.244
# Minibatch: 301 | Cost:    22914.459
# Minibatch: 321 | Cost:    23483.500
# Minibatch: 341 | Cost:    22950.443
# Minibatch: 361 | Cost:    23235.641
# Minibatch: 381 | Cost:    22763.566
# Minibatch: 401 | Cost:    23327.855
# Minibatch: 421 | Cost:    22417.168
# Minibatch: 441 | Cost:    23396.213
# Minibatch: 461 | Cost:    22896.828
# Minibatch: 481 | Cost:    24111.570
# Epoch:     031 | AvgCost: 4292215.448
# Minibatch: 001 | Cost:    121202.734
# Minibatch: 021 | Cost:    54879.562
# Minibatch: 041 | Cost:    23284.928
# Minibatch: 061 | Cost:    6006.876
# Minibatch: 081 | Cost:    4535.101
# Minibatch: 101 | Cost:    3495.745
# Minibatch: 121 | Cost:    3233.305
# Minibatch: 141 | Cost:    3134.168
# Minibatch: 161 | Cost:    3895.811
# Minibatch: 181 | Cost:    5730.079
# Minibatch: 201 | Cost:    4202.650
# Minibatch: 221 | Cost:    3791.557
# Minibatch: 241 | Cost:    3349.178
# Minibatch: 261 | Cost:    4494.810
# Minibatch: 281 | Cost:    6841.968
# Minibatch: 301 | Cost:    4216.592
# Minibatch: 321 | Cost:    4776.904
# Minibatch: 341 | Cost:    5163.874
# Minibatch: 361 | Cost:    6087.367
# Minibatch: 381 | Cost:    4023.536
# Minibatch: 401 | Cost:    7206.414
# Minibatch: 421 | Cost:    4256.339
# Minibatch: 441 | Cost:    4068.837
# Minibatch: 461 | Cost:    6083.768
# Minibatch: 481 | Cost:    3981.865
# Epoch:     032 | AvgCost: 418637.466
# Minibatch: 001 | Cost:    27398.266
# Minibatch: 021 | Cost:    16024.080
# Minibatch: 041 | Cost:    13685.349
# Minibatch: 061 | Cost:    12887.539
# Minibatch: 081 | Cost:    14389.081
# Minibatch: 101 | Cost:    13264.791
# Minibatch: 121 | Cost:    15486.448
# Minibatch: 141 | Cost:    13904.963
# Minibatch: 161 | Cost:    14261.555
# Minibatch: 181 | Cost:    13188.808
# Minibatch: 201 | Cost:    13998.755
# Minibatch: 221 | Cost:    13111.349
# Minibatch: 241 | Cost:    16446.355
# Minibatch: 261 | Cost:    13786.266
# Minibatch: 281 | Cost:    13047.119
# Minibatch: 301 | Cost:    13956.307
# Minibatch: 321 | Cost:    171273.328
# Minibatch: 341 | Cost:    13810.998
# Minibatch: 361 | Cost:    13891.322
# Minibatch: 381 | Cost:    13036.350
# Minibatch: 401 | Cost:    13284.549
# Minibatch: 421 | Cost:    38177.582
# Minibatch: 441 | Cost:    14184.883
# Minibatch: 461 | Cost:    14240.870
# Minibatch: 481 | Cost:    14029.185
# Epoch:     033 | AvgCost: 1089834.420
# Minibatch: 001 | Cost:    142428.344
# Minibatch: 021 | Cost:    139437.969
# Minibatch: 041 | Cost:    164552.344
# Minibatch: 061 | Cost:    166726.547
# Minibatch: 081 | Cost:    161949.047
# Minibatch: 101 | Cost:    174289.969
# Minibatch: 121 | Cost:    185162.969
# Minibatch: 141 | Cost:    173599.656
# Minibatch: 161 | Cost:    179856.781
# Minibatch: 181 | Cost:    171012.953
# Minibatch: 201 | Cost:    175072.766
# Minibatch: 221 | Cost:    167709.938
# Minibatch: 241 | Cost:    143776.625
# Minibatch: 261 | Cost:    168392.625
# Minibatch: 281 | Cost:    174885.328
# Minibatch: 301 | Cost:    171656.719
# Minibatch: 321 | Cost:    168154.156
# Minibatch: 341 | Cost:    171987.141
# Minibatch: 361 | Cost:    172686.422
# Minibatch: 381 | Cost:    168020.281
# Minibatch: 401 | Cost:    152931.031
# Minibatch: 421 | Cost:    175829.531
# Minibatch: 441 | Cost:    176768.578
# Minibatch: 461 | Cost:    162921.062
# Minibatch: 481 | Cost:    173885.844
# Epoch:     034 | AvgCost: 2097163.034
# Minibatch: 001 | Cost:    42118.852
# Minibatch: 021 | Cost:    114517.578
# Minibatch: 041 | Cost:    116237.977
# Minibatch: 061 | Cost:    115212.125
# Minibatch: 081 | Cost:    113446.977
# Minibatch: 101 | Cost:    114716.523
# Minibatch: 121 | Cost:    114771.023
# Minibatch: 141 | Cost:    114025.773
# Minibatch: 161 | Cost:    115970.359
# Minibatch: 181 | Cost:    114314.797
# Minibatch: 201 | Cost:    105975.516
# Minibatch: 221 | Cost:    114001.703
# Minibatch: 241 | Cost:    114429.164
# Minibatch: 261 | Cost:    114952.109
# Minibatch: 281 | Cost:    114067.773
# Minibatch: 301 | Cost:    111864.289
# Minibatch: 321 | Cost:    113697.000
# Minibatch: 341 | Cost:    113559.859
# Minibatch: 361 | Cost:    113903.453
# Minibatch: 381 | Cost:    114893.297
# Minibatch: 401 | Cost:    113121.414
# Minibatch: 421 | Cost:    115345.422
# Minibatch: 441 | Cost:    113727.391
# Minibatch: 461 | Cost:    116902.914
# Minibatch: 481 | Cost:    112963.336
# Epoch:     035 | AvgCost: 2701306.829
# Minibatch: 001 | Cost:    32387.791
# Minibatch: 021 | Cost:    14371.747
# Minibatch: 041 | Cost:    12787.169
# Minibatch: 061 | Cost:    11984.973
# Minibatch: 081 | Cost:    51626.586
# Minibatch: 101 | Cost:    11907.673
# Minibatch: 121 | Cost:    12072.323
# Minibatch: 141 | Cost:    12684.312
# Minibatch: 161 | Cost:    77714.625
# Minibatch: 181 | Cost:    13218.175
# Minibatch: 201 | Cost:    12678.175
# Minibatch: 221 | Cost:    12254.604
# Minibatch: 241 | Cost:    23873.289
# Minibatch: 261 | Cost:    13076.883
# Minibatch: 281 | Cost:    158656.250
# Minibatch: 301 | Cost:    11686.744
# Minibatch: 321 | Cost:    12464.749
# Minibatch: 341 | Cost:    11661.584
# Minibatch: 361 | Cost:    11984.479
# Minibatch: 381 | Cost:    12974.030
# Minibatch: 401 | Cost:    12762.643
# Minibatch: 421 | Cost:    21366.879
# Minibatch: 441 | Cost:    11776.419
# Minibatch: 461 | Cost:    46009.664
# Minibatch: 481 | Cost:    13860.516
# Epoch:     036 | AvgCost: 4924899.031
# Minibatch: 001 | Cost:    173230.219
# Minibatch: 021 | Cost:    4945.625
# Minibatch: 041 | Cost:    7616.849
# Minibatch: 061 | Cost:    4500.502
# Minibatch: 081 | Cost:    6344.622
# Minibatch: 101 | Cost:    4996.165
# Minibatch: 121 | Cost:    4211.901
# Minibatch: 141 | Cost:    5531.091
# Minibatch: 161 | Cost:    5140.182
# Minibatch: 181 | Cost:    4524.281
# Minibatch: 201 | Cost:    5181.986
# Minibatch: 221 | Cost:    4736.011
# Minibatch: 241 | Cost:    5498.667
# Minibatch: 261 | Cost:    5187.819
# Minibatch: 281 | Cost:    4946.478
# Minibatch: 301 | Cost:    4433.666
# Minibatch: 321 | Cost:    5591.220
# Minibatch: 341 | Cost:    5667.956
# Minibatch: 361 | Cost:    5279.735
# Minibatch: 381 | Cost:    5539.791
# Minibatch: 401 | Cost:    5099.209
# Minibatch: 421 | Cost:    5170.938
# Minibatch: 441 | Cost:    5220.300
# Minibatch: 461 | Cost:    5118.007
# Minibatch: 481 | Cost:    5014.499
# Epoch:     037 | AvgCost: 1477685.112
# Minibatch: 001 | Cost:    111353.203
# Minibatch: 021 | Cost:    23462.871
# Minibatch: 041 | Cost:    16996.145
# Minibatch: 061 | Cost:    16281.019
# Minibatch: 081 | Cost:    41531.648
# Minibatch: 101 | Cost:    13252.240
# Minibatch: 121 | Cost:    24396.760
# Minibatch: 141 | Cost:    21545.445
# Minibatch: 161 | Cost:    20521.760
# Minibatch: 181 | Cost:    13100.290
# Minibatch: 201 | Cost:    16627.777
# Minibatch: 221 | Cost:    17611.334
# Minibatch: 241 | Cost:    16276.984
# Minibatch: 261 | Cost:    25560.602
# Minibatch: 281 | Cost:    10286.273
# Minibatch: 301 | Cost:    10651.579
# Minibatch: 321 | Cost:    229377.203
# Minibatch: 341 | Cost:    48704.059
# Minibatch: 361 | Cost:    12529.952
# Minibatch: 381 | Cost:    35434.414
# Minibatch: 401 | Cost:    47130.055
# Minibatch: 421 | Cost:    12761.041
# Minibatch: 441 | Cost:    28914.203
# Minibatch: 461 | Cost:    26534.832
# Minibatch: 481 | Cost:    10705.411
# Epoch:     038 | AvgCost: 1247186.223
# Minibatch: 001 | Cost:    75963.172
# Minibatch: 021 | Cost:    16898.975
# Minibatch: 041 | Cost:    12820.576
# Minibatch: 061 | Cost:    12800.718
# Minibatch: 081 | Cost:    11895.778
# Minibatch: 101 | Cost:    83970.938
# Minibatch: 121 | Cost:    10984.362
# Minibatch: 141 | Cost:    11207.014
# Minibatch: 161 | Cost:    13053.107
# Minibatch: 181 | Cost:    11274.069
# Minibatch: 201 | Cost:    19661.217
# Minibatch: 221 | Cost:    10572.231
# Minibatch: 241 | Cost:    11326.631
# Minibatch: 261 | Cost:    11025.627
# Minibatch: 281 | Cost:    10568.309
# Minibatch: 301 | Cost:    12366.373
# Minibatch: 321 | Cost:    10322.412
# Minibatch: 341 | Cost:    10427.843
# Minibatch: 361 | Cost:    9942.481
# Minibatch: 381 | Cost:    11550.377
# Minibatch: 401 | Cost:    11763.331
# Minibatch: 421 | Cost:    11519.955
# Minibatch: 441 | Cost:    11909.257
# Minibatch: 461 | Cost:    12406.029
# Minibatch: 481 | Cost:    11208.338
# Epoch:     039 | AvgCost: 5722301.629
# Minibatch: 001 | Cost:    75416.156
# Minibatch: 021 | Cost:    4988.938
# Minibatch: 041 | Cost:    5043.286
# Minibatch: 061 | Cost:    6148.806
# Minibatch: 081 | Cost:    4308.615
# Minibatch: 101 | Cost:    3335.388
# Minibatch: 121 | Cost:    1386.867
# Minibatch: 141 | Cost:    3919.571
# Minibatch: 161 | Cost:    1240.903
# Minibatch: 181 | Cost:    418467.281
# Minibatch: 201 | Cost:    1363.816
# Minibatch: 221 | Cost:    1134.809
# Minibatch: 241 | Cost:    1039.490
# Minibatch: 261 | Cost:    679.949
# Minibatch: 281 | Cost:    1403.482
# Minibatch: 301 | Cost:    1007.726
# Minibatch: 321 | Cost:    3872.609
# Minibatch: 341 | Cost:    727.937
# Minibatch: 361 | Cost:    1496.690
# Minibatch: 381 | Cost:    728.264
# Minibatch: 401 | Cost:    2527.280
# Minibatch: 421 | Cost:    1022.276
# Minibatch: 441 | Cost:    951.302
# Minibatch: 461 | Cost:    797.038
# Minibatch: 481 | Cost:    15001.322
# Epoch:     040 | AvgCost: 1938765.861
# Minibatch: 001 | Cost:    43044.098
# Minibatch: 021 | Cost:    61633.273
# Minibatch: 041 | Cost:    64940.836
# Minibatch: 061 | Cost:    63364.930
# Minibatch: 081 | Cost:    62135.617
# Minibatch: 101 | Cost:    60159.500
# Minibatch: 121 | Cost:    63265.352
# Minibatch: 141 | Cost:    62419.961
# Minibatch: 161 | Cost:    63427.102
# Minibatch: 181 | Cost:    62849.426
# Minibatch: 201 | Cost:    62102.137
# Minibatch: 221 | Cost:    62446.273
# Minibatch: 241 | Cost:    58375.176
# Minibatch: 261 | Cost:    63333.508
# Minibatch: 281 | Cost:    63138.289
# Minibatch: 301 | Cost:    63657.699
# Minibatch: 321 | Cost:    62174.617
# Minibatch: 341 | Cost:    61563.758
# Minibatch: 361 | Cost:    62504.988
# Minibatch: 381 | Cost:    62753.957
# Minibatch: 401 | Cost:    62009.824
# Minibatch: 421 | Cost:    63273.137
# Minibatch: 441 | Cost:    63068.805
# Minibatch: 461 | Cost:    62051.594
# Minibatch: 481 | Cost:    65755.039
# Epoch:     041 | AvgCost: 4745176.632
# Minibatch: 001 | Cost:    3279.510
# Minibatch: 021 | Cost:    7488.564
# Minibatch: 041 | Cost:    10820.236
# Minibatch: 061 | Cost:    10425.150
# Minibatch: 081 | Cost:    10462.084
# Minibatch: 101 | Cost:    11942.832
# Minibatch: 121 | Cost:    11947.764
# Minibatch: 141 | Cost:    11810.489
# Minibatch: 161 | Cost:    12617.057
# Minibatch: 181 | Cost:    12198.641
# Minibatch: 201 | Cost:    11984.005
# Minibatch: 221 | Cost:    12144.516
# Minibatch: 241 | Cost:    27616.191
# Minibatch: 261 | Cost:    12146.104
# Minibatch: 281 | Cost:    12566.303
# Minibatch: 301 | Cost:    13412.487
# Minibatch: 321 | Cost:    12487.275
# Minibatch: 341 | Cost:    13030.588
# Minibatch: 361 | Cost:    12181.239
# Minibatch: 381 | Cost:    13384.604
# Minibatch: 401 | Cost:    26398.262
# Minibatch: 421 | Cost:    12488.992
# Minibatch: 441 | Cost:    13154.956
# Minibatch: 461 | Cost:    12196.264
# Minibatch: 481 | Cost:    12791.544
# Epoch:     042 | AvgCost: 3568074.179
# Minibatch: 001 | Cost:    87695.836
# Minibatch: 021 | Cost:    127219.141
# Minibatch: 041 | Cost:    126235.836
# Minibatch: 061 | Cost:    127119.703
# Minibatch: 081 | Cost:    123826.938
# Minibatch: 101 | Cost:    125883.078
# Minibatch: 121 | Cost:    127533.039
# Minibatch: 141 | Cost:    126563.484
# Minibatch: 161 | Cost:    125970.273
# Minibatch: 181 | Cost:    126582.312
# Minibatch: 201 | Cost:    129960.859
# Minibatch: 221 | Cost:    126762.289
# Minibatch: 241 | Cost:    126652.859
# Minibatch: 261 | Cost:    125461.711
# Minibatch: 281 | Cost:    125121.898
# Minibatch: 301 | Cost:    125827.398
# Minibatch: 321 | Cost:    127813.547
# Minibatch: 341 | Cost:    125881.188
# Minibatch: 361 | Cost:    126251.148
# Minibatch: 381 | Cost:    126565.016
# Minibatch: 401 | Cost:    124121.484
# Minibatch: 421 | Cost:    126168.688
# Minibatch: 441 | Cost:    126317.797
# Minibatch: 461 | Cost:    126636.391
# Minibatch: 481 | Cost:    125881.750
# Epoch:     043 | AvgCost: 2198040.376
# Minibatch: 001 | Cost:    139703.578
# Minibatch: 021 | Cost:    175262.484
# Minibatch: 041 | Cost:    176154.156
# Minibatch: 061 | Cost:    176582.953
# Minibatch: 081 | Cost:    176832.969
# Minibatch: 101 | Cost:    176652.953
# Minibatch: 121 | Cost:    176643.859
# Minibatch: 141 | Cost:    176599.938
# Minibatch: 161 | Cost:    176320.156
# Minibatch: 181 | Cost:    176026.188
# Minibatch: 201 | Cost:    175916.672
# Minibatch: 221 | Cost:    175006.172
# Minibatch: 241 | Cost:    176344.391
# Minibatch: 261 | Cost:    176543.062
# Minibatch: 281 | Cost:    180295.141
# Minibatch: 301 | Cost:    175977.406
# Minibatch: 321 | Cost:    175844.047
# Minibatch: 341 | Cost:    176248.062
# Minibatch: 361 | Cost:    175848.719
# Minibatch: 381 | Cost:    189957.438
# Minibatch: 401 | Cost:    174555.422
# Minibatch: 421 | Cost:    175227.625
# Minibatch: 441 | Cost:    177113.344
# Minibatch: 461 | Cost:    175848.922
# Minibatch: 481 | Cost:    183671.328
# Epoch:     044 | AvgCost: 767580.863
# Minibatch: 001 | Cost:    5903.532
# Minibatch: 021 | Cost:    2325.434
# Minibatch: 041 | Cost:    2088.225
# Minibatch: 061 | Cost:    1431.225
# Minibatch: 081 | Cost:    3548.364
# Minibatch: 101 | Cost:    3604.388
# Minibatch: 121 | Cost:    3650.548
# Minibatch: 141 | Cost:    2269.819
# Minibatch: 161 | Cost:    3230.513
# Minibatch: 181 | Cost:    4240.883
# Minibatch: 201 | Cost:    2688.674
# Minibatch: 221 | Cost:    3003.376
# Minibatch: 241 | Cost:    2453.224
# Minibatch: 261 | Cost:    2684.283
# Minibatch: 281 | Cost:    2375.278
# Minibatch: 301 | Cost:    4115.929
# Minibatch: 321 | Cost:    3729.118
# Minibatch: 341 | Cost:    3267.000
# Minibatch: 361 | Cost:    3331.161
# Minibatch: 381 | Cost:    2112.272
# Minibatch: 401 | Cost:    1880.338
# Minibatch: 421 | Cost:    2602.025
# Minibatch: 441 | Cost:    2187.084
# Minibatch: 461 | Cost:    13609.686
# Minibatch: 481 | Cost:    2547.757
# Epoch:     045 | AvgCost: 3627752.275
# Minibatch: 001 | Cost:    118419.672
# Minibatch: 021 | Cost:    6790.946
# Minibatch: 041 | Cost:    4898.659
# Minibatch: 061 | Cost:    13034.172
# Minibatch: 081 | Cost:    6295.581
# Minibatch: 101 | Cost:    11589.883
# Minibatch: 121 | Cost:    5731.636
# Minibatch: 141 | Cost:    7262.030
# Minibatch: 161 | Cost:    5847.093
# Minibatch: 181 | Cost:    4805.509
# Minibatch: 201 | Cost:    5187.985
# Minibatch: 221 | Cost:    10045.631
# Minibatch: 241 | Cost:    6482.842
# Minibatch: 261 | Cost:    5105.855
# Minibatch: 281 | Cost:    4963.761
# Minibatch: 301 | Cost:    6605.877
# Minibatch: 321 | Cost:    5667.438
# Minibatch: 341 | Cost:    4647.382
# Minibatch: 361 | Cost:    8679.931
# Minibatch: 381 | Cost:    5891.825
# Minibatch: 401 | Cost:    4315.533
# Minibatch: 421 | Cost:    8670.576
# Minibatch: 441 | Cost:    5498.004
# Minibatch: 461 | Cost:    4880.473
# Minibatch: 481 | Cost:    4324.422
# Epoch:     046 | AvgCost: 4883790.400
# Minibatch: 001 | Cost:    9201.494
# Minibatch: 021 | Cost:    1222.252
# Minibatch: 041 | Cost:    2155.435
# Minibatch: 061 | Cost:    1049.535
# Minibatch: 081 | Cost:    1605.747
# Minibatch: 101 | Cost:    3641.456
# Minibatch: 121 | Cost:    2123.600
# Minibatch: 141 | Cost:    2068.411
# Minibatch: 161 | Cost:    2136.618
# Minibatch: 181 | Cost:    2482.537
# Minibatch: 201 | Cost:    3956.433
# Minibatch: 221 | Cost:    3529.538
# Minibatch: 241 | Cost:    3197.520
# Minibatch: 261 | Cost:    2329.875
# Minibatch: 281 | Cost:    3321.545
# Minibatch: 301 | Cost:    2092.001
# Minibatch: 321 | Cost:    3786.570
# Minibatch: 341 | Cost:    2582.778
# Minibatch: 361 | Cost:    2628.545
# Minibatch: 381 | Cost:    3035.029
# Minibatch: 401 | Cost:    2663.982
# Minibatch: 421 | Cost:    2589.651
# Minibatch: 441 | Cost:    2615.862
# Minibatch: 461 | Cost:    2663.614
# Minibatch: 481 | Cost:    2516.228
# Epoch:     047 | AvgCost: 2368457.128
# Minibatch: 001 | Cost:    152137.844
# Minibatch: 021 | Cost:    30654.807
# Minibatch: 041 | Cost:    27364.906
# Minibatch: 061 | Cost:    27363.125
# Minibatch: 081 | Cost:    25491.766
# Minibatch: 101 | Cost:    27194.574
# Minibatch: 121 | Cost:    35121.219
# Minibatch: 141 | Cost:    25682.809
# Minibatch: 161 | Cost:    24864.199
# Minibatch: 181 | Cost:    25948.238
# Minibatch: 201 | Cost:    27767.473
# Minibatch: 221 | Cost:    24658.332
# Minibatch: 241 | Cost:    25892.613
# Minibatch: 261 | Cost:    26054.434
# Minibatch: 281 | Cost:    24498.318
# Minibatch: 301 | Cost:    24927.123
# Minibatch: 321 | Cost:    25618.895
# Minibatch: 341 | Cost:    25866.447
# Minibatch: 361 | Cost:    24610.291
# Minibatch: 381 | Cost:    25154.938
# Minibatch: 401 | Cost:    25118.098
# Minibatch: 421 | Cost:    25977.672
# Minibatch: 441 | Cost:    25497.223
# Minibatch: 461 | Cost:    26417.004
# Minibatch: 481 | Cost:    28367.598
# Epoch:     048 | AvgCost: 2677781.278
# Minibatch: 001 | Cost:    79931.797
# Minibatch: 021 | Cost:    163019.641
# Minibatch: 041 | Cost:    161090.125
# Minibatch: 061 | Cost:    163820.188
# Minibatch: 081 | Cost:    162288.531
# Minibatch: 101 | Cost:    157056.156
# Minibatch: 121 | Cost:    153198.766
# Minibatch: 141 | Cost:    155216.672
# Minibatch: 161 | Cost:    152474.344
# Minibatch: 181 | Cost:    151164.578
# Minibatch: 201 | Cost:    152017.531
# Minibatch: 221 | Cost:    152999.031
# Minibatch: 241 | Cost:    150801.719
# Minibatch: 261 | Cost:    158802.641
# Minibatch: 281 | Cost:    153570.812
# Minibatch: 301 | Cost:    154657.734
# Minibatch: 321 | Cost:    155776.578
# Minibatch: 341 | Cost:    153088.844
# Minibatch: 361 | Cost:    152775.797
# Minibatch: 381 | Cost:    152459.266
# Minibatch: 401 | Cost:    153249.500
# Minibatch: 421 | Cost:    152478.797
# Minibatch: 441 | Cost:    148345.672
# Minibatch: 461 | Cost:    151748.641
# Minibatch: 481 | Cost:    151716.031
# Epoch:     049 | AvgCost: 1178481.636
# Minibatch: 001 | Cost:    135053.297
# Minibatch: 021 | Cost:    30514.291
# Minibatch: 041 | Cost:    30134.941
# Minibatch: 061 | Cost:    31631.400
# Minibatch: 081 | Cost:    29914.402
# Minibatch: 101 | Cost:    29710.604
# Minibatch: 121 | Cost:    29166.822
# Minibatch: 141 | Cost:    28980.146
# Minibatch: 161 | Cost:    28998.078
# Minibatch: 181 | Cost:    30749.688
# Minibatch: 201 | Cost:    30082.969
# Minibatch: 221 | Cost:    28625.422
# Minibatch: 241 | Cost:    31453.879
# Minibatch: 261 | Cost:    29011.006
# Minibatch: 281 | Cost:    28966.100
# Minibatch: 301 | Cost:    29736.182
# Minibatch: 321 | Cost:    28814.584
# Minibatch: 341 | Cost:    34807.848
# Minibatch: 361 | Cost:    29289.316
# Minibatch: 381 | Cost:    29989.938
# Minibatch: 401 | Cost:    29100.943
# Minibatch: 421 | Cost:    28935.697
# Minibatch: 441 | Cost:    29955.000
# Minibatch: 461 | Cost:    29025.188
# Minibatch: 481 | Cost:    27870.338
# Epoch:     050 | AvgCost: 2941580.029
# Minibatch: 001 | Cost:    188764.844
# Minibatch: 021 | Cost:    15195.131
# Minibatch: 041 | Cost:    15451.725
# Minibatch: 061 | Cost:    13045.985
# Minibatch: 081 | Cost:    12414.167
# Minibatch: 101 | Cost:    12500.616
# Minibatch: 121 | Cost:    11720.273
# Minibatch: 141 | Cost:    11514.477
# Minibatch: 161 | Cost:    11810.614
# Minibatch: 181 | Cost:    14679.955
# Minibatch: 201 | Cost:    11820.748
# Minibatch: 221 | Cost:    11276.935
# Minibatch: 241 | Cost:    11632.037
# Minibatch: 261 | Cost:    11301.815
# Minibatch: 281 | Cost:    11506.388
# Minibatch: 301 | Cost:    13946.740
# Minibatch: 321 | Cost:    11288.764
# Minibatch: 341 | Cost:    11413.533
# Minibatch: 361 | Cost:    11145.805
# Minibatch: 381 | Cost:    11137.059
# Minibatch: 401 | Cost:    11389.073
# Minibatch: 421 | Cost:    11357.310
# Minibatch: 441 | Cost:    11282.199
# Minibatch: 461 | Cost:    15094.734
# Minibatch: 481 | Cost:    11040.556
# Epoch:     051 | AvgCost: 3462829.311
# Minibatch: 001 | Cost:    35966.969
# Minibatch: 021 | Cost:    4121.937
# Minibatch: 041 | Cost:    3739.904
# Minibatch: 061 | Cost:    4230.059
# Minibatch: 081 | Cost:    5598.204
# Minibatch: 101 | Cost:    5137.169
# Minibatch: 121 | Cost:    10327.430
# Minibatch: 141 | Cost:    5761.954
# Minibatch: 161 | Cost:    5881.656
# Minibatch: 181 | Cost:    7406.919
# Minibatch: 201 | Cost:    5817.495
# Minibatch: 221 | Cost:    5883.146
# Minibatch: 241 | Cost:    6412.722
# Minibatch: 261 | Cost:    6851.130
# Minibatch: 281 | Cost:    7284.970
# Minibatch: 301 | Cost:    6359.864
# Minibatch: 321 | Cost:    6590.765
# Minibatch: 341 | Cost:    7779.714
# Minibatch: 361 | Cost:    7123.923
# Minibatch: 381 | Cost:    6329.064
# Minibatch: 401 | Cost:    6588.496
# Minibatch: 421 | Cost:    6545.011
# Minibatch: 441 | Cost:    8291.385
# Minibatch: 461 | Cost:    6802.896
# Minibatch: 481 | Cost:    6544.286
# Epoch:     052 | AvgCost: 1060447.515
# Minibatch: 001 | Cost:    400882.750
# Minibatch: 021 | Cost:    35252.930
# Minibatch: 041 | Cost:    30133.150
# Minibatch: 061 | Cost:    30156.371
# Minibatch: 081 | Cost:    29830.121
# Minibatch: 101 | Cost:    29738.066
# Minibatch: 121 | Cost:    30289.150
# Minibatch: 141 | Cost:    31137.438
# Minibatch: 161 | Cost:    30375.766
# Minibatch: 181 | Cost:    29683.740
# Minibatch: 201 | Cost:    29778.479
# Minibatch: 221 | Cost:    29486.588
# Minibatch: 241 | Cost:    29288.662
# Minibatch: 261 | Cost:    29297.209
# Minibatch: 281 | Cost:    29301.551
# Minibatch: 301 | Cost:    29211.650
# Minibatch: 321 | Cost:    29324.277
# Minibatch: 341 | Cost:    29175.209
# Minibatch: 361 | Cost:    30847.793
# Minibatch: 381 | Cost:    29705.309
# Minibatch: 401 | Cost:    29444.363
# Minibatch: 421 | Cost:    29299.434
# Minibatch: 441 | Cost:    29353.359
# Minibatch: 461 | Cost:    29228.994
# Minibatch: 481 | Cost:    29819.803
# Epoch:     053 | AvgCost: 1421519.819
# Minibatch: 001 | Cost:    198058.422
# Minibatch: 021 | Cost:    84333.906
# Minibatch: 041 | Cost:    86927.898
# Minibatch: 061 | Cost:    85658.000
# Minibatch: 081 | Cost:    85898.062
# Minibatch: 101 | Cost:    86436.375
# Minibatch: 121 | Cost:    83979.938
# Minibatch: 141 | Cost:    84273.039
# Minibatch: 161 | Cost:    91528.039
# Minibatch: 181 | Cost:    89129.320
# Minibatch: 201 | Cost:    99229.688
# Minibatch: 221 | Cost:    84991.141
# Minibatch: 241 | Cost:    86420.219
# Minibatch: 261 | Cost:    86990.820
# Minibatch: 281 | Cost:    85328.984
# Minibatch: 301 | Cost:    86237.258
# Minibatch: 321 | Cost:    86383.180
# Minibatch: 341 | Cost:    84874.523
# Minibatch: 361 | Cost:    99189.828
# Minibatch: 381 | Cost:    85399.984
# Minibatch: 401 | Cost:    88825.516
# Minibatch: 421 | Cost:    96567.703
# Minibatch: 441 | Cost:    87365.672
# Minibatch: 461 | Cost:    85764.656
# Minibatch: 481 | Cost:    89037.961
# Epoch:     054 | AvgCost: 2397861.543
# Minibatch: 001 | Cost:    223072.297
# Minibatch: 021 | Cost:    128922.047
# Minibatch: 041 | Cost:    132466.281
# Minibatch: 061 | Cost:    130577.062
# Minibatch: 081 | Cost:    124272.625
# Minibatch: 101 | Cost:    131912.594
# Minibatch: 121 | Cost:    125867.109
# Minibatch: 141 | Cost:    128511.125
# Minibatch: 161 | Cost:    129176.078
# Minibatch: 181 | Cost:    125991.000
# Minibatch: 201 | Cost:    126493.609
# Minibatch: 221 | Cost:    124080.148
# Minibatch: 241 | Cost:    121394.641
# Minibatch: 261 | Cost:    122298.172
# Minibatch: 281 | Cost:    122450.273
# Minibatch: 301 | Cost:    118741.750
# Minibatch: 321 | Cost:    119489.922
# Minibatch: 341 | Cost:    120106.711
# Minibatch: 361 | Cost:    132046.531
# Minibatch: 381 | Cost:    128522.500
# Minibatch: 401 | Cost:    126516.977
# Minibatch: 421 | Cost:    125130.000
# Minibatch: 441 | Cost:    128025.547
# Minibatch: 461 | Cost:    123938.328
# Minibatch: 481 | Cost:    121524.250
# Epoch:     055 | AvgCost: 1269173.146
# Minibatch: 001 | Cost:    64283.293
# Minibatch: 021 | Cost:    34940.242
# Minibatch: 041 | Cost:    35468.605
# Minibatch: 061 | Cost:    35613.789
# Minibatch: 081 | Cost:    43455.648
# Minibatch: 101 | Cost:    36350.016
# Minibatch: 121 | Cost:    36004.914
# Minibatch: 141 | Cost:    35943.699
# Minibatch: 161 | Cost:    36146.977
# Minibatch: 181 | Cost:    35863.340
# Minibatch: 201 | Cost:    36491.449
# Minibatch: 221 | Cost:    36174.820
# Minibatch: 241 | Cost:    36099.695
# Minibatch: 261 | Cost:    36006.273
# Minibatch: 281 | Cost:    36259.453
# Minibatch: 301 | Cost:    36235.633
# Minibatch: 321 | Cost:    35991.242
# Minibatch: 341 | Cost:    36325.375
# Minibatch: 361 | Cost:    36468.469
# Minibatch: 381 | Cost:    36008.844
# Minibatch: 401 | Cost:    41643.680
# Minibatch: 421 | Cost:    36093.352
# Minibatch: 441 | Cost:    35908.816
# Minibatch: 461 | Cost:    36034.625
# Minibatch: 481 | Cost:    45248.102
# Epoch:     056 | AvgCost: 2590828.995
# Minibatch: 001 | Cost:    45460.062
# Minibatch: 021 | Cost:    4143.510
# Minibatch: 041 | Cost:    17070.043
# Minibatch: 061 | Cost:    5134.296
# Minibatch: 081 | Cost:    19848.348
# Minibatch: 101 | Cost:    6038.280
# Minibatch: 121 | Cost:    5223.816
# Minibatch: 141 | Cost:    12609.361
# Minibatch: 161 | Cost:    5256.575
# Minibatch: 181 | Cost:    23931.379
# Minibatch: 201 | Cost:    5681.926
# Minibatch: 221 | Cost:    7195.403
# Minibatch: 241 | Cost:    5432.670
# Minibatch: 261 | Cost:    19411.459
# Minibatch: 281 | Cost:    22106.463
# Minibatch: 301 | Cost:    5391.495
# Minibatch: 321 | Cost:    8371.788
# Minibatch: 341 | Cost:    5041.747
# Minibatch: 361 | Cost:    5730.904
# Minibatch: 381 | Cost:    53142.352
# Minibatch: 401 | Cost:    5242.990
# Minibatch: 421 | Cost:    6942.440
# Minibatch: 441 | Cost:    6318.716
# Minibatch: 461 | Cost:    5414.539
# Minibatch: 481 | Cost:    18808.727
# Epoch:     057 | AvgCost: 5187129.035
# Minibatch: 001 | Cost:    312416.875
# Minibatch: 021 | Cost:    10403.357
# Minibatch: 041 | Cost:    1904.749
# Minibatch: 061 | Cost:    1089.083
# Minibatch: 081 | Cost:    3687.645
# Minibatch: 101 | Cost:    7854.776
# Minibatch: 121 | Cost:    4657.030
# Minibatch: 141 | Cost:    15733.339
# Minibatch: 161 | Cost:    4538.792
# Minibatch: 181 | Cost:    13401.591
# Minibatch: 201 | Cost:    3737.292
# Minibatch: 221 | Cost:    5669.888
# Minibatch: 241 | Cost:    1065.749
# Minibatch: 261 | Cost:    4731.237
# Minibatch: 281 | Cost:    2010.689
# Minibatch: 301 | Cost:    3569.762
# Minibatch: 321 | Cost:    3390.682
# Minibatch: 341 | Cost:    6971.512
# Minibatch: 361 | Cost:    1042.955
# Minibatch: 381 | Cost:    1007.163
# Minibatch: 401 | Cost:    1588.240
# Minibatch: 421 | Cost:    4753.958
# Minibatch: 441 | Cost:    2079.254
# Minibatch: 461 | Cost:    1526.645
# Minibatch: 481 | Cost:    4716.011
# Epoch:     058 | AvgCost: 348237.364
# Minibatch: 001 | Cost:    80624.898
# Minibatch: 021 | Cost:    66542.141
# Minibatch: 041 | Cost:    65794.641
# Minibatch: 061 | Cost:    68556.734
# Minibatch: 081 | Cost:    67150.250
# Minibatch: 101 | Cost:    71457.602
# Minibatch: 121 | Cost:    67111.828
# Minibatch: 141 | Cost:    66675.070
# Minibatch: 161 | Cost:    67419.781
# Minibatch: 181 | Cost:    66492.398
# Minibatch: 201 | Cost:    66954.453
# Minibatch: 221 | Cost:    64119.664
# Minibatch: 241 | Cost:    66619.914
# Minibatch: 261 | Cost:    66908.797
# Minibatch: 281 | Cost:    214906.750
# Minibatch: 301 | Cost:    65520.176
# Minibatch: 321 | Cost:    65423.551
# Minibatch: 341 | Cost:    66841.531
# Minibatch: 361 | Cost:    67187.141
# Minibatch: 381 | Cost:    66244.750
# Minibatch: 401 | Cost:    66315.055
# Minibatch: 421 | Cost:    67809.109
# Minibatch: 441 | Cost:    69668.547
# Minibatch: 461 | Cost:    68043.188
# Minibatch: 481 | Cost:    66786.914
# Epoch:     059 | AvgCost: 3374922.121
# Minibatch: 001 | Cost:    24098.457
# Minibatch: 021 | Cost:    11687.525
# Minibatch: 041 | Cost:    11755.712
# Minibatch: 061 | Cost:    13820.271
# Minibatch: 081 | Cost:    11548.201
# Minibatch: 101 | Cost:    19305.764
# Minibatch: 121 | Cost:    9875.561
# Minibatch: 141 | Cost:    13204.686
# Minibatch: 161 | Cost:    11314.636
# Minibatch: 181 | Cost:    13858.216
# Minibatch: 201 | Cost:    13620.557
# Minibatch: 221 | Cost:    11278.647
# Minibatch: 241 | Cost:    14966.154
# Minibatch: 261 | Cost:    15410.490
# Minibatch: 281 | Cost:    13637.896
# Minibatch: 301 | Cost:    16103.912
# Minibatch: 321 | Cost:    13617.939
# Minibatch: 341 | Cost:    14551.783
# Minibatch: 361 | Cost:    11557.975
# Minibatch: 381 | Cost:    13629.278
# Minibatch: 401 | Cost:    15050.119
# Minibatch: 421 | Cost:    14094.811
# Minibatch: 441 | Cost:    14215.151
# Minibatch: 461 | Cost:    12197.991
# Minibatch: 481 | Cost:    12520.733
# Epoch:     060 | AvgCost: 3869503.239

# %%
a = toy_data_generator.create_dataset(1)
np.reshape(a[0][0], (-1, 5))
# Out:
# array([[   2.,    2., 1000., 1000., 1000.]])

# %%
# sess.run(['hidden2'])
ans = []
# saver.restore(sess, save_path='./autoencoder.ckpt')
with tf.Session(graph=g) as sess:
    sess.run(tf.global_variables_initializer())
#     saver.restore(sess, save_path='./autoencoder.ckpt')
    for i in range(len(a)):
        
        temp = sess.run(['reduced_dim'], feed_dict={'input:0': np.reshape(a[i][0], (-1, 5))})
        print('{}'.format(temp))
        ans.append(temp)
# Out:
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
# [None]
