# %%
from TPM_from_VCS.data import toy_data_generator

a = toy_data_generator.create_dataset(1)

len(a)

a[:2]
# Out:
# Number of nodes currently : 86
# dist_matrix shape : [[-1.02052827  0.54781616]
#  [ 0.37318853  1.42229549]
#  [-1.3081008  -0.24044806]
#  [-0.17420542 -0.24866829]
#  [-0.26520789  1.20713596]
#  [ 1.75472708 -0.78168198]
#  [ 0.47533677  1.5227707 ]
#  [-0.47391531 -2.43752736]
#  [ 1.60517729 -1.04724809]
#  [ 0.65952511  0.50623871]
#  [-0.48733238 -0.55500155]
#  [-0.18450797  1.02775984]
#  [-0.08272369  1.05840587]
#  [ 1.02766189 -0.75952229]
#  [ 2.2258112  -0.46981611]
#  [ 0.49792271  0.82492209]
#  [-0.77313509 -0.45435481]
#  [-0.49566853 -0.01184144]
#  [ 0.57898537 -0.66227358]
#  [ 1.33292115 -0.39404436]
#  [-2.50408469 -1.37373969]
#  [ 1.13563154 -0.43091352]
#  [-1.10028295  0.19820952]
#  [ 0.0407598   0.78145406]
#  [ 0.06493754 -0.15102838]
#  [-0.01601653  1.5072508 ]
#  [-1.60482532  1.78616035]
#  [-0.2363808  -2.42559596]
#  [-1.63738569 -0.70135006]
#  [ 0.88141613  0.34600913]
#  [ 0.08442389  0.15584683]
#  [ 0.9601634  -0.70860884]
# ...

# %%
a
